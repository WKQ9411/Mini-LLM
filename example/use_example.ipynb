# %% [markdown]
# 1. 通过注册进 transformers 的方式使用

# %%
import mini_models  # 先导入用于注册自定义的 Mini-LLM 模型
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
model = AutoModelForCausalLM.from_pretrained("WKQ9411/Mini-Llama3-100M-SFT")
tokenizer = AutoTokenizer.from_pretrained("WKQ9411/Mini-Llama3-100M-SFT")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
messages = [{"role": "user", "content": "你好，你是谁？"}]
formatted_text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
input_ids = tokenizer(formatted_text, return_tensors="pt")["input_ids"].to(model.device)
response = model.generate(input_ids, max_new_tokens=100)
response = tokenizer.decode(response[0][len(input_ids[0]):], skip_special_tokens=True)
print(response)
# Out:
# 你好！我是Mini-LLM，一个由开发者WKQ创建的聊天机器人助手。

# %% [markdown]
# 2. 通过自定义接口使用

# %%
from mini_models import get_model_and_config, list_models, get_model_info

# %%
Model, Config = get_model_and_config("mini_llama3")
model = Model.from_pretrained("../output/sft_mini_llama3")
tokenizer = AutoTokenizer.from_pretrained("../mini_tokenizer")
model = model.to(device)
print(list_models())
print(get_model_info(model))
# Out:
# ['mini_llama3', 'mini_deepseekv3']
# ({'specific_params': 100538112}, {'architecture': 'Dense', 'trainable_params': '100.5 M'})

# %%
messages = [{"role": "user", "content": "你好，你是谁？"}]
formatted_text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
input_ids = tokenizer(formatted_text, return_tensors="pt")["input_ids"].to(model.device)
response = model.generate(input_ids, max_new_tokens=100)
response = tokenizer.decode(response[0][len(input_ids[0]):], skip_special_tokens=True)
print(response)
# Out:
# 你好！我是Mini-LLM，一个由开发者WKQ创建的聊天机器人助手。
